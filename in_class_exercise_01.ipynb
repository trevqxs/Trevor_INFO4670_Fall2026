# %% [markdown]
# <a href="https://colab.research.google.com/github/trevqxs/Trevor_INFO4670_Fall2026/blob/main/in_class_exercise_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My first pthon code for NLP

# %%
# !pip install -u "tensorflow-text"
